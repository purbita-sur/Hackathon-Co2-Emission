# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
country=pd.read_csv("Country.csv")

# %%
country_notes=pd.read_csv("CountryNotes.csv")

# %%
footnotes=pd.read_csv("Footnotes.csv")

# %%
series=pd.read_csv("Series.csv")
series_notes=pd.read_csv("SeriesNotes.csv")

# %%
indicators=pd.read_csv("Indicators.csv")

# %%
country.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
country_notes.head()
# Out:
#   Countrycode         Seriescode  \
# 0         ABW  EG.EGY.PRIM.PP.KD
# 1         ABW     EG.ELC.RNEW.ZS
# 2         ABW     EG.FEC.RNEW.ZS
# 3         ABW        SM.POP.NETM
# 4         ABW        SM.POP.TOTL
#
#                                          Description
# 0  Sources: Estimated based on UN Energy Statisti...
# 1               Sources: UN Energy Statistics (2014)
# 2               Sources: UN Energy Statistics (2014)
# 3  Data sources : United Nations World Population...
# 4  Estimates are derived from data on foreign-bor...

# %%
footnotes.head()
# Out:
#   Countrycode         Seriescode    Year  \
# 0         ABW     AG.LND.FRST.K2  YR1990
# 1         ABW     AG.LND.FRST.K2  YR2000
# 2         ABW     AG.LND.FRST.K2  YR2005
# 3         ABW  BX.KLT.DINV.CD.WD  YR1987
# 4         ABW  BX.KLT.DINV.CD.WD  YR1988
#
#                                          Description
# 0                                      Not specified
# 1                                      Not specified
# 2                                      Not specified
# 3  Source: United Nations Conference on Trade and...
# 4  Source: United Nations Conference on Trade and...

# %%
series.head()
# Out:
#              SeriesCode                                              Topic  \
# 0        BN.KLT.DINV.CD  Economic Policy & Debt: Balance of payments: C...
# 1  BX.KLT.DINV.WD.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 2     BX.KLT.DINV.CD.WD  Economic Policy & Debt: Balance of payments: C...
# 3     BM.KLT.DINV.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 4        BN.TRF.KOGT.CD  Economic Policy & Debt: Balance of payments: C...
#
#                                        IndicatorName ShortDefinition  \
# 0  Foreign direct investment, net (BoP, current US$)             NaN
# 1  Foreign direct investment, net inflows (% of GDP)             NaN
# 2  Foreign direct investment, net inflows (BoP, c...             NaN
# 3  Foreign direct investment, net outflows (% of ...             NaN
# 4             Net capital account (BoP, current US$)             NaN
#
#                                       LongDefinition UnitOfMeasure  \
# ...

# %%
indicators.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
series_notes.head()
# Out:
#           Seriescode    Year  \
# 0        SP.ADO.TFRT  YR1960
# 1     SP.DYN.AMRT.FE  YR1960
# 2     SP.DYN.AMRT.MA  YR1960
# 3  SP.DYN.TO65.FE.ZS  YR1960
# 4  SP.DYN.TO65.MA.ZS  YR1960
#
#                                          Description
# 0         Interpolated using data for 1957 and 1962.
# 1  Interpolated using data for 1957 and 1962, if ...
# 2  Interpolated using data for 1957 and 1962, if ...
# 3         Interpolated using data for 1957 and 1962.
# 4         Interpolated using data for 1957 and 1962.

# %%
country.columns
# Out:
# Index(['CountryCode', 'ShortName', 'TableName', 'LongName', 'Alpha2Code',
#        'CurrencyUnit', 'SpecialNotes', 'Region', 'IncomeGroup', 'Wb2Code',
#        'NationalAccountsBaseYear', 'NationalAccountsReferenceYear',
#        'SnaPriceValuation', 'LendingCategory', 'OtherGroups',
#        'SystemOfNationalAccounts', 'AlternativeConversionFactor',
#        'PppSurveyYear', 'BalanceOfPaymentsManualInUse',
#        'ExternalDebtReportingStatus', 'SystemOfTrade',
#        'GovernmentAccountingConcept', 'ImfDataDisseminationStandard',
#        'LatestPopulationCensus', 'LatestHouseholdSurvey',
#        'SourceOfMostRecentIncomeAndExpenditureData',
#        'VitalRegistrationComplete', 'LatestAgriculturalCensus',
#        'LatestIndustrialData', 'LatestTradeData', 'LatestWaterWithdrawalData'],
#       dtype='object')

# %%
country_notes.columns
# Out:
# Index(['Countrycode', 'Seriescode', 'Description'], dtype='object')

# %%
series.columns
# Out:
# Index(['SeriesCode', 'Topic', 'IndicatorName', 'ShortDefinition',
#        'LongDefinition', 'UnitOfMeasure', 'Periodicity', 'BasePeriod',
#        'OtherNotes', 'AggregationMethod', 'LimitationsAndExceptions',
#        'NotesFromOriginalSource', 'GeneralComments', 'Source',
#        'StatisticalConceptAndMethodology', 'DevelopmentRelevance',
#        'RelatedSourceLinks', 'OtherWebLinks', 'RelatedIndicators',
#        'LicenseType'],
#       dtype='object')

# %%
series_notes.columns
# Out:
# Index(['Seriescode', 'Year', 'Description'], dtype='object')

# %%
footnotes.columns
# Out:
# Index(['Countrycode', 'Seriescode', 'Year', 'Description'], dtype='object')

# %%
indicators.columns
# Out:
# Index(['CountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', 'Year',
#        'Value'],
#       dtype='object')

# %%
co2=indicators[indicators['IndicatorName']=='CO2 emissions (metric tons per capita)']

# %%
series['ShortDefinition']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#        ...
# 1315    NaN
# 1316    NaN
# 1317    NaN
# 1318    NaN
# 1319    NaN
# 1320    NaN
# 1321    NaN
# 1322    NaN
# 1323    NaN
# 1324    NaN
# 1325    NaN
# 1326    NaN
# 1327    NaN
# 1328    NaN
# 1329    NaN
# 1330    NaN
# 1331    NaN
# 1332    NaN
# 1333    NaN
# 1334    NaN
# 1335    NaN
# 1336    NaN
# 1337    NaN
# 1338    NaN
# 1339    NaN
# 1340    NaN
# 1341    NaN
# 1342    NaN
# 1343    NaN
# 1344    NaN
# Name: ShortDefinition, Length: 1345, dtype: object

# %%
india_co2=co2[co2['CountryCode']=='IND']

# %%
indicators[indicators['CountryName']=='Japan']
# Out:
#         CountryName CountryCode  \
# 12804         Japan         JPN
# 12805         Japan         JPN
# 12806         Japan         JPN
# 12807         Japan         JPN
# 12808         Japan         JPN
# 12809         Japan         JPN
# 12810         Japan         JPN
# 12811         Japan         JPN
# 12812         Japan         JPN
# 12813         Japan         JPN
# 12814         Japan         JPN
# 12815         Japan         JPN
# 12816         Japan         JPN
# 12817         Japan         JPN
# 12818         Japan         JPN
# 12819         Japan         JPN
# 12820         Japan         JPN
# 12821         Japan         JPN
# 12822         Japan         JPN
# 12823         Japan         JPN
# 12824         Japan         JPN
# 12825         Japan         JPN
# 12826         Japan         JPN
# 12827         Japan         JPN
# 12828         Japan         JPN
# 12829         Japan         JPN
# 12830         Japan         JPN
# 12831         Japan         JPN
# ...

# %%
china_co2=co2[co2['CountryCode']=='CHN']

# %%
japan_co2=co2[co2['CountryCode']=='JPN']

# %%
indicators
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# 5        Arab World         ARB
# 6        Arab World         ARB
# 7        Arab World         ARB
# 8        Arab World         ARB
# 9        Arab World         ARB
# 10       Arab World         ARB
# 11       Arab World         ARB
# 12       Arab World         ARB
# 13       Arab World         ARB
# 14       Arab World         ARB
# 15       Arab World         ARB
# 16       Arab World         ARB
# 17       Arab World         ARB
# 18       Arab World         ARB
# 19       Arab World         ARB
# 20       Arab World         ARB
# 21       Arab World         ARB
# 22       Arab World         ARB
# 23       Arab World         ARB
# 24       Arab World         ARB
# 25       Arab World         ARB
# 26       Arab World         ARB
# 27       Arab World         ARB
# ...

# %% [markdown]
# # MASKING

# %%
temp=indicators[indicators['IndicatorCode']=='EN.ATM.CO2E.GF.ZS']

# %%
india_gf_zs=temp[temp['CountryCode']=='IND']
china_gf_zs=temp[temp['CountryCode']=='CHN']
japan_gf_zs=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.ATM.CO2E.LF.ZS']
india_lf_zs=temp[temp['CountryCode']=='IND']
china_lf_zs=temp[temp['CountryCode']=='CHN']
japan_lf_zs=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.ATM.CO2E.EG.ZS']
india_eg=temp[temp['CountryCode']=='IND']
china_eg=temp[temp['CountryCode']=='CHN']
japan_eg=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.ATM.CO2E.PC']
india_pc=temp[temp['CountryCode']=='IND']
china_pc=temp[temp['CountryCode']=='CHN']
japan_pc=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.CO2.ETOT.ZS']
india_etot=temp[temp['CountryCode']=='IND']
china_etot=temp[temp['CountryCode']=='CHN']
japan_etot=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.CO2.MANF.ZS']
india_manf=temp[temp['CountryCode']=='IND']
china_manf=temp[temp['CountryCode']=='CHN']
japan_manf=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.CO2.OTHX.ZS']
india_othx=temp[temp['CountryCode']=='IND']
china_othx=temp[temp['CountryCode']=='CHN']
japan_othx=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.CO2.BLDG.ZS']
india_bldg=temp[temp['CountryCode']=='IND']
china_bldg=temp[temp['CountryCode']=='CHN']
japan_bldg=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.CO2.TRAN.ZS']
india_tran=temp[temp['CountryCode']=='IND']
china_tran=temp[temp['CountryCode']=='CHN']
japan_tran=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.ATM.CO2E.SF.ZS']
india_sf_zs=temp[temp['CountryCode']=='IND']
china_sf_zs=temp[temp['CountryCode']=='CHN']
japan_sf_zs=temp[temp['CountryCode']=='JPN']

# %%
temp=indicators[indicators['IndicatorCode']=='EN.ATM.CO2E.KD.GD']
india_gd=temp[temp['CountryCode']=='IND']
china_gd=temp[temp['CountryCode']=='CHN']

# %%
india_sf_zs
# Out:
#         CountryName CountryCode  \
# 11582         India         IND
# 36518         India         IND
# 64054         India         IND
# 92498         India         IND
# 121295        India         IND
# 151965        India         IND
# 183701        India         IND
# 215619        India         IND
# 248234        India         IND
# 281018        India         IND
# 328986        India         IND
# 394154        India         IND
# 463152        India         IND
# 532852        India         IND
# 602742        India         IND
# 673981        India         IND
# 746828        India         IND
# 821382        India         IND
# 896835        India         IND
# 972729        India         IND
# 1051397       India         IND
# 1134485       India         IND
# 1219190       India         IND
# 1304406       India         IND
# 1389989       India         IND
# 1476467       India         IND
# 1564193       India         IND
# 1652906       India         IND
# ...

# %% [markdown]
# # GRAPHS

# %%
year=india_pc['Year']
values_india=india_pc['Value']
values_china=china_pc['Value']
#values_japan=japan_pc['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions (metric tons per capita')
plt.legend()
plt.show()

# %%
year=india_lf_zs['Year']
values_india=india_lf_zs['Value']
values_china=china_lf_zs['Value']
#values_japan=japan_lf_zs['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions from liquid fuel consumption ')
plt.legend()
plt.show()

# %%
year=india_gf_zs['Year']
values_india=india_gf_zs['Value']
values_china=china_gf_zs['Value']
#values_japan=japan_gf_zs['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions from gaseous fuel consumption ')
plt.legend()
plt.show()

# %%
year=india_etot['Year']
values_india=india_etot['Value']
values_china=china_etot['Value']
#values_japan=japan_etot['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions from electricity and heat production')
plt.legend()
plt.show()

# %%
year=india_othx['Year']
values_india=india_othx['Value']
values_china=china_othx['Value']
#values_japan=japan_othx['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions from other sectors')
plt.legend()
plt.show()

# %%
year=india_bldg['Year']
values_india=india_bldg['Value']
values_china=china_bldg['Value']
#values_japan=japan_bldg['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions from residential buildings')
plt.legend()
plt.show()

# %%
year=india_tran['Year']
values_india=india_tran['Value']
values_china=china_tran['Value']
#values_japan=japan_tran['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions from transport')
plt.legend()
plt.show()

# %%
year=india_sf_zs['Year']
values_india=india_sf_zs['Value']
values_china=china_sf_zs['Value']
#values_japan=japan_sf_zs['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions from solid fuel consumption ')
plt.legend()
plt.show()

# %%
year=india_eg['Year']
values_india=india_eg['Value']
values_china=china_eg['Value']
#values_japan=japan_eg['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 Intensity')
plt.legend()
plt.show()

# %%
year=india_manf['Year']
values_india=india_manf['Value']
values_china=china_manf['Value']
#values_japan=japan_manf['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions from manufacturing industries')
plt.legend()
plt.show()

# %%
year=india_gd['Year']
values_india=india_gd['Value']
values_china=china_gd['Value']
#values_japan=japan_manf['Value']
plt.plot(year,values_india,label="India")
plt.plot(year,values_china,label="China")
#plt.plot(year,values_japan,label="Japan")
plt.xlabel('Year')
plt.ylabel('CO2 emissions (kg per 2005 US$ of GDP)')
plt.legend()
plt.show()

# %%
indicators['IndicatorName'].head(80).values
# Out:
# array(['Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Age dependency ratio (% of working-age population)',
#        'Age dependency ratio, old (% of working-age population)',
#        'Age dependency ratio, young (% of working-age population)',
#        'Arms exports (SIPRI trend indicator values)',
#        'Arms imports (SIPRI trend indicator values)',
#        'Birth rate, crude (per 1,000 people)', 'CO2 emissions (kt)',
#        'CO2 emissions (metric tons per capita)',
#        'CO2 emissions from gaseous fuel consumption (% of total)',
#        'CO2 emissions from liquid fuel consumption (% of total)',
#        'CO2 emissions from liquid fuel consumption (kt)',
#        'CO2 emissions from solid fuel consumption (% of total)',
#        'Death rate, crude (per 1,000 people)',
#        'Fertility rate, total (births per woman)',
#        'Fixed telephone subscriptions',
#        'Fixed telephone subscriptions (per 100 people)',
# ...

# %%
population=indicators[indicators['IndicatorName']=='Population, total']

# %%
india_pop=population[population['CountryName']=='India']
china_pop=population[population['CountryName']=='China']

# %%
india_pop
# Out:
#         CountryName CountryCode      IndicatorName IndicatorCode  Year  \
# 11758         India         IND  Population, total   SP.POP.TOTL  1960
# 36711         India         IND  Population, total   SP.POP.TOTL  1961
# 64254         India         IND  Population, total   SP.POP.TOTL  1962
# 92704         India         IND  Population, total   SP.POP.TOTL  1963
# 121503        India         IND  Population, total   SP.POP.TOTL  1964
# 152180        India         IND  Population, total   SP.POP.TOTL  1965
# 183909        India         IND  Population, total   SP.POP.TOTL  1966
# 215830        India         IND  Population, total   SP.POP.TOTL  1967
# 248446        India         IND  Population, total   SP.POP.TOTL  1968
# 281234        India         IND  Population, total   SP.POP.TOTL  1969
# 329307        India         IND  Population, total   SP.POP.TOTL  1970
# 394521        India         IND  Population, total   SP.POP.TOTL  1971
# ...

# %%
len(values_pop_in)
# Out:
# 55

# %%
len(values_india_co2)
# Out:
# 52

# %%
len(values_pop_in.unique())
# Out:
# 55
